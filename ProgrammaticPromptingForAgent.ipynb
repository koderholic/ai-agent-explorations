# %% [markdown]
# <a href="https://colab.research.google.com/github/koderholic/ai-agent-explorations/blob/main/ProgrammaticPromptingForAgent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !!pip install litellm

# Important!!!
#
# <---- Set your 'OPENAI_API_KEY' as a secret over there with the "key" icon
#
#
import os
from google.colab import userdata
api_key = userdata.get('OPENAI_API_KEY')
os.environ['OPENAI_API_KEY'] = api_key

# %%
from litellm import completion
from typing import List, Dict

def generate_response(messages: List[Dict]) -> str:
    """Call LLM to get response"""
    response = completion(
        model="openai/gpt-4o",
        messages=messages,
        max_tokens=1024
    )
    return response.choices[0].message.content

user_input = input("What problem do you want to generate a python code or function for?")

messages = [
    {"role": "system", "content":"What problem do you want to generate a python code or function for?"},
    {"role":"user", "content":"I want to generate a python code to help me soleve "+user_input}
]

response1 = generate_response(messages)
print("First response !!!! >> ")
print(response1)

# Follow-up prompt maintainign context

messages = [
    {"role": "system", "content":"What problem do you want to generate a python code or function for?"},
    {"role":"user", "content":"I want to generate a python code to help me soleve "+user_input},

    # Follow-up prompt
    {"role":"assistant", "content":response1},

    {"role": "user", "content":"Add comprehensive documentation to the generated python code from the previous response. The generated documentation SHOULD capture: Function description, Parameter descriptions, Return value description, Example usage, Edge cases"}
]

response2 = generate_response(messages)
print("Second response !!!! >> ")
print(response2)


# Follow-up prompt maintainign context
messages = [
    {"role": "system", "content":"What problem do you want to generate a python code or function for?"},
    {"role":"user", "content":"I want to generate a python code to help me soleve "+user_input},

    # Follow-up prompt
    {"role":"assistant", "content":response1},

    {"role": "user", "content":"Add comprehensive documentation to the generated python code from the previous response. The generated documentation SHOULD capture: Function description, Parameter descriptions, Return value description, Example usage, Edge cases"},

    # Follow-up prompt
    {"role":"assistant", "content":response2},

    {"role":"user", "content": "Add test cases to the generated code with doumentatin from previous response, using Python’s unittest framework. Tests should cover: Basic functionality, Edge cases, Error cases, Various input scenarios"}
]


response3 = generate_response(messages)
print("Second response !!!! >> ")
print(response3)

# save response3 to a python file
with open("generatedPythonCodeFromPrompt.py", "w") as f:
    f.write(response3)
# Out:
# What problem do you want to generate a python code or function for?find an element in a tree with n-depth
# First response !!!! >>
# To find an element in a tree with n-depth, you can use either a Depth-First Search (DFS) or a Breadth-First Search (BFS) approach. These are common methods for traversing trees and searching for elements.
#
# Below is an example of how you can implement a DFS to find an element in a tree:
#
# ```python
# class TreeNode:
#     def __init__(self, value):
#         self.value = value
#         self.children = []
#
# def dfs_find(node, target, depth, max_depth):
#     """
#     Perform a DFS to find the target element in a tree with a specified depth limit (max_depth).
#
#     :param node: Current node in the tree
#     :param target: Target value to find
#     :param depth: Current depth in the tree
#     :param max_depth: Maximum depth to search within
#     :return: True if target is found, False otherwise
#     """
# ...
